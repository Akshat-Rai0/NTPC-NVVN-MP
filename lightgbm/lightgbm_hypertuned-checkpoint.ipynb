# %%
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error
import numpy as np

df = pd.read_csv('GOA_Final_dataset.csv')

df['datetime'] = pd.to_datetime(df['datetime'])
df = df.set_index('datetime').sort_index()


# Features and target
feature_cols = [
    'temp_weighted', 'month', 'holiday',
    'is_weekend', 'hour', 'minute',
    'y_lag_24h', 'y_lag_7d' , 'y_lag_1'
]

X = df[feature_cols]
y = df['hourly_demand_met_mw']

# Temporal split — train / val / test
X_train = X[df.index < '2025-07-01']
y_train = y[df.index < '2025-07-01']

X_val   = X[(df.index >= '2025-07-01') & (df.index < '2026-01-01')]
y_val   = y[(df.index >= '2025-07-01') & (df.index < '2026-01-01')]

X_test  = X[df.index >= '2026-01-01']
y_test  = y[df.index >= '2026-01-01']

print(f'Train: {X_train.shape}')
print(f'Val:   {X_val.shape}')
print(f'Test:  {X_test.shape}')

# Train — early stopping on validation
train_data = lgb.Dataset(X_train, label=y_train)
val_data   = lgb.Dataset(X_val,   label=y_val)

params = {
    'objective':         'regression',
    'metric':            'rmse',
    'learning_rate':     0.05,
    'num_leaves':        63,
    'min_child_samples': 20,
    'feature_fraction':  0.8,
    'bagging_fraction':  0.8,
    'bagging_freq':      5,
    'verbose':           -1
}

model = lgb.train(
    params,
    train_data,
    num_boost_round=1000,
    valid_sets=[val_data],
    callbacks=[lgb.early_stopping(50), lgb.log_evaluation(100)]
)

# Evaluate on validation
y_val_pred = model.predict(X_val)
val_mape   = np.mean(np.abs((y_val - y_val_pred) / y_val)) * 100
print(f'\nVal MAPE:  {val_mape:.2f}%')

# Evaluate on test
y_pred = model.predict(X_test)
mae    = mean_absolute_error(y_test, y_pred)
rmse   = np.sqrt(np.mean((y_test - y_pred) ** 2))
mape   = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print(f'\nTest MAE:  {mae:.2f} MW')
print(f'Test RMSE: {rmse:.2f} MW')
print(f'Test MAPE: {mape:.2f}%')
# Out:
# Train: (51840, 9)
# Val:   (17664, 9)
# Test:  (8637, 9)
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 5.3143
# [200]	valid_0's rmse: 4.68284
# [300]	valid_0's rmse: 4.63264
# [400]	valid_0's rmse: 4.62208
# Early stopping, best iteration is:
# [355]	valid_0's rmse: 4.61808
#
# Val MAPE:  0.67%
#
# Test MAE:  3.16 MW
# Test RMSE: 4.31 MW
# Test MAPE: 0.64%

# %%
avg_mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print(f'MAPE: {avg_mape:.2f}%')
# Out:
# MAPE: 0.64%

# %%
results = pd.DataFrame({'actual': y_test, 'predicted': y_pred}, index=X_test.index)
results['mape'] = np.abs((results['actual'] - results['predicted']) / results['actual']) * 100

# Average MAPE per day
daily_mape = results.groupby(results.index.date)['mape'].mean()
print(daily_mape)
print(f'Avg daily MAPE: {daily_mape.mean():.2f}%')
# Out:
# 2026-01-01    0.778523
# 2026-01-02    0.930973
# 2026-01-03    0.657565
# 2026-01-04    0.548222
# 2026-01-05    0.658460
#                 ...
# 2026-03-27    0.710647
# 2026-03-28    0.773841
# 2026-03-29    0.522847
# 2026-03-30    0.435568
# 2026-03-31    0.611174
# Name: mape, Length: 90, dtype: float64
# Avg daily MAPE: 0.64%

# %%
results = pd.DataFrame({
    'actual':    y_test, 
    'predicted': y_pred
}, index=X_test.index)

results['error'] = np.abs(results['actual'] - results['predicted'])
results['mape']  = np.abs((results['actual'] - results['predicted']) / results['actual']) * 100

# Worst hours
print(results.nlargest(10, 'error'))

# Error by hour of day
print(results.groupby(results.index.hour)['mape'].mean())
# Out:
#                       actual   predicted      error      mape
# datetime
# 2026-02-28 23:45:00  462.355  495.092071  32.737071  7.080505
# 2026-02-28 23:30:00  499.740  531.102779  31.362779  6.275819
# 2026-03-01 00:00:00  424.970  455.294410  30.324410  7.135659
# 2026-01-02 16:45:00  515.695  485.848155  29.846845  5.787693
# 2026-01-02 16:30:00  485.710  456.297938  29.412062  6.055478
# 2026-02-28 23:15:00  537.125  565.280674  28.155674  5.241922
# 2026-01-02 16:15:00  455.725  428.114111  27.610889  6.058673
# 2026-01-02 17:00:00  545.680  518.477784  27.202216  4.985012
# 2026-03-02 16:45:00  515.695  490.023350  25.671650  4.978068
# 2026-03-02 16:30:00  485.710  460.302473  25.407527  5.231008
# datetime
# 0     0.448508
# 1     0.405844
# 2     0.370804
# 3     0.472366
# 4     0.490268
# 5     0.539579
# 6     0.856678
# 7     0.803458
# 8     0.758662
# 9     0.746718
# 10    0.721794
# 11    0.586368
# 12    0.569898
# 13    0.736540
# 14    0.786675
# 15    0.638428
# 16    0.774917
# 17    0.618702
# 18    0.838263
# 19    0.750519
# 20    0.629532
# 21    0.556114
# 22    0.613882
# 23    0.619057
# Name: mape, dtype: float64

# %%
import optuna

def objective(trial):
    params = {
        'objective':         'regression',
        'metric':            'rmse',
        'learning_rate':     trial.suggest_float('learning_rate', 0.01, 0.1),
        'num_leaves':        trial.suggest_int('num_leaves', 20, 150),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 50),
        'feature_fraction':  trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction':  trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'bagging_freq':      5,
        'verbose':           -1
    }
    
    train_data = lgb.Dataset(X_train, label=y_train)
    val_data   = lgb.Dataset(X_val,   label=y_val)
    
    model = lgb.train(
        params,
        train_data,
        num_boost_round=1000,
        valid_sets=[val_data],
        callbacks=[lgb.early_stopping(50), lgb.log_evaluation(-1)]
    )
    
    y_val_pred = model.predict(X_val)
    return np.mean(np.abs((y_val - y_val_pred) / y_val)) * 100

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

print('Best params:', study.best_params)
print('Best val MAPE:', study.best_value)
# Out:
# [I 2026-06-17 11:10:39,316] A new study created in memory with name: no-name-fb8a5165-2f52-432b-ae12-da397694bcc3
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:10:46,248] Trial 0 finished with value: 0.7550641274319373 and parameters: {'learning_rate': 0.08354767855165786, 'num_leaves': 91, 'min_child_samples': 17, 'feature_fraction': 0.6660605441089374, 'bagging_fraction': 0.7787765481790868}. Best is trial 0 with value: 0.7550641274319373.
# Early stopping, best iteration is:
# [339]	valid_0's rmse: 5.1006
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:10:47,829] Trial 1 finished with value: 0.6112572694107867 and parameters: {'learning_rate': 0.06827908845977758, 'num_leaves': 40, 'min_child_samples': 37, 'feature_fraction': 0.9471723785191306, 'bagging_fraction': 0.6084140219693704}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [146]	valid_0's rmse: 4.26312
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:10:49,351] Trial 2 finished with value: 0.6388858570109966 and parameters: {'learning_rate': 0.08606798593615145, 'num_leaves': 39, 'min_child_samples': 43, 'feature_fraction': 0.8957505530985689, 'bagging_fraction': 0.8090965177699707}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [137]	valid_0's rmse: 4.38746
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [856]	valid_0's rmse: 4.93341
# [I 2026-06-17 11:11:05,070] Trial 3 finished with value: 0.7286619899431777 and parameters: {'learning_rate': 0.027138761098017435, 'num_leaves': 83, 'min_child_samples': 35, 'feature_fraction': 0.6355064361361631, 'bagging_fraction': 0.9880030034046173}. Best is trial 1 with value: 0.6112572694107867.
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:11:14,635] Trial 4 finished with value: 0.6173620938614766 and parameters: {'learning_rate': 0.01614898372383255, 'num_leaves': 98, 'min_child_samples': 36, 'feature_fraction': 0.9867741200635244, 'bagging_fraction': 0.7517285949600696}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [430]	valid_0's rmse: 4.30365
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 5.12296
# [I 2026-06-17 11:11:41,788] Trial 5 finished with value: 0.7685385566436258 and parameters: {'learning_rate': 0.03814931091696191, 'num_leaves': 87, 'min_child_samples': 48, 'feature_fraction': 0.6040051509922861, 'bagging_fraction': 0.8230694873328169}. Best is trial 1 with value: 0.6112572694107867.
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:11:46,357] Trial 6 finished with value: 0.6486922500371554 and parameters: {'learning_rate': 0.04363180409023256, 'num_leaves': 49, 'min_child_samples': 14, 'feature_fraction': 0.8888350783366008, 'bagging_fraction': 0.8557141616723373}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [345]	valid_0's rmse: 4.45751
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:11:48,145] Trial 7 finished with value: 0.6379584125843955 and parameters: {'learning_rate': 0.08508440334070017, 'num_leaves': 39, 'min_child_samples': 31, 'feature_fraction': 0.8589789212498794, 'bagging_fraction': 0.6629742301911987}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [174]	valid_0's rmse: 4.39836
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 4.8816
# [I 2026-06-17 11:11:57,824] Trial 8 finished with value: 0.7282078373688403 and parameters: {'learning_rate': 0.018174315748004814, 'num_leaves': 42, 'min_child_samples': 35, 'feature_fraction': 0.6049960701501772, 'bagging_fraction': 0.8149557961150701}. Best is trial 1 with value: 0.6112572694107867.
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:05,713] Trial 9 finished with value: 0.7008738662356087 and parameters: {'learning_rate': 0.03921748149484431, 'num_leaves': 51, 'min_child_samples': 20, 'feature_fraction': 0.6837053681606438, 'bagging_fraction': 0.9893940798129084}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [711]	valid_0's rmse: 4.78861
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:12,307] Trial 10 finished with value: 0.7086066069956704 and parameters: {'learning_rate': 0.0633722918886537, 'num_leaves': 146, 'min_child_samples': 24, 'feature_fraction': 0.7551991507798466, 'bagging_fraction': 0.607203968384517}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [203]	valid_0's rmse: 4.80978
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:16,322] Trial 11 finished with value: 0.6201345184706514 and parameters: {'learning_rate': 0.06278672555070193, 'num_leaves': 136, 'min_child_samples': 41, 'feature_fraction': 0.9973881142375951, 'bagging_fraction': 0.7046216853210485}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [115]	valid_0's rmse: 4.32118
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:31,917] Trial 12 finished with value: 0.6175033526911738 and parameters: {'learning_rate': 0.010214240125866948, 'num_leaves': 116, 'min_child_samples': 27, 'feature_fraction': 0.9753096103505219, 'bagging_fraction': 0.7104674924264868}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [680]	valid_0's rmse: 4.30334
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:35,226] Trial 13 finished with value: 0.6464180899756421 and parameters: {'learning_rate': 0.06460409486655996, 'num_leaves': 69, 'min_child_samples': 41, 'feature_fraction': 0.9250840320734128, 'bagging_fraction': 0.6065704959376073}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [204]	valid_0's rmse: 4.46295
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:37,940] Trial 14 finished with value: 0.640477790354671 and parameters: {'learning_rate': 0.05080043740286749, 'num_leaves': 25, 'min_child_samples': 34, 'feature_fraction': 0.8163208603527109, 'bagging_fraction': 0.9182656167938386}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [465]	valid_0's rmse: 4.39801
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:40,444] Trial 15 finished with value: 0.6166283611732889 and parameters: {'learning_rate': 0.09641498474304334, 'num_leaves': 112, 'min_child_samples': 49, 'feature_fraction': 0.9482943976238221, 'bagging_fraction': 0.7369699856975147}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [72]	valid_0's rmse: 4.2895
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:43,415] Trial 16 finished with value: 0.6570708562244848 and parameters: {'learning_rate': 0.09935264065640784, 'num_leaves': 120, 'min_child_samples': 50, 'feature_fraction': 0.9369621833624473, 'bagging_fraction': 0.6608189077219405}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [88]	valid_0's rmse: 4.50415
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:45,728] Trial 17 finished with value: 0.6540032753751225 and parameters: {'learning_rate': 0.09890914351034827, 'num_leaves': 66, 'min_child_samples': 47, 'feature_fraction': 0.8107598329576482, 'bagging_fraction': 0.6637036002105361}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [126]	valid_0's rmse: 4.47338
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:48,714] Trial 18 finished with value: 0.6169646056642465 and parameters: {'learning_rate': 0.07515186483229883, 'num_leaves': 105, 'min_child_samples': 42, 'feature_fraction': 0.9505374396603713, 'bagging_fraction': 0.8915519234967764}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [103]	valid_0's rmse: 4.2988
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:51,489] Trial 19 finished with value: 0.6544625867527992 and parameters: {'learning_rate': 0.07290516337291579, 'num_leaves': 75, 'min_child_samples': 29, 'feature_fraction': 0.8418132338051634, 'bagging_fraction': 0.716510205981753}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [143]	valid_0's rmse: 4.50598
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:55,045] Trial 20 finished with value: 0.6629461819078419 and parameters: {'learning_rate': 0.09408073726116142, 'num_leaves': 131, 'min_child_samples': 44, 'feature_fraction': 0.9024737643788291, 'bagging_fraction': 0.7665576247107057}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [97]	valid_0's rmse: 4.54403
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:12:57,797] Trial 21 finished with value: 0.6182314474167162 and parameters: {'learning_rate': 0.07607703333327036, 'num_leaves': 106, 'min_child_samples': 39, 'feature_fraction': 0.9512100528726992, 'bagging_fraction': 0.9018744233200047}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [89]	valid_0's rmse: 4.29844
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:00,614] Trial 22 finished with value: 0.6184489084405924 and parameters: {'learning_rate': 0.0725377217434137, 'num_leaves': 108, 'min_child_samples': 46, 'feature_fraction': 0.9501149005896168, 'bagging_fraction': 0.9272483856292163}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [85]	valid_0's rmse: 4.29769
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:01,857] Trial 23 finished with value: 0.6129349042736775 and parameters: {'learning_rate': 0.05485883226877608, 'num_leaves': 23, 'min_child_samples': 38, 'feature_fraction': 0.9608833695975679, 'bagging_fraction': 0.8722919795358233}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [168]	valid_0's rmse: 4.26053
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:03,804] Trial 24 finished with value: 0.6278998095243257 and parameters: {'learning_rate': 0.05338924490921764, 'num_leaves': 24, 'min_child_samples': 39, 'feature_fraction': 0.8675829212248387, 'bagging_fraction': 0.854402367717801}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [261]	valid_0's rmse: 4.32916
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:05,559] Trial 25 finished with value: 0.6244011561029831 and parameters: {'learning_rate': 0.05459315974613928, 'num_leaves': 21, 'min_child_samples': 10, 'feature_fraction': 0.9201327483952102, 'bagging_fraction': 0.9457852355749814}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [311]	valid_0's rmse: 4.30428
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:08,777] Trial 26 finished with value: 0.6136867991100099 and parameters: {'learning_rate': 0.03239691768060929, 'num_leaves': 55, 'min_child_samples': 32, 'feature_fraction': 0.9700117024638667, 'bagging_fraction': 0.6448264622778191}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [245]	valid_0's rmse: 4.27707
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:12,472] Trial 27 finished with value: 0.6148840080401669 and parameters: {'learning_rate': 0.03175005492944952, 'num_leaves': 59, 'min_child_samples': 25, 'feature_fraction': 0.9970517666044664, 'bagging_fraction': 0.6410098227879106}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [244]	valid_0's rmse: 4.284
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:14,336] Trial 28 finished with value: 0.6122875879563215 and parameters: {'learning_rate': 0.04642057975633809, 'num_leaves': 35, 'min_child_samples': 32, 'feature_fraction': 0.9658983286216343, 'bagging_fraction': 0.639081664469931}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [200]	valid_0's rmse: 4.26795
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:17,111] Trial 29 finished with value: 0.6287185513075767 and parameters: {'learning_rate': 0.04696080137238393, 'num_leaves': 32, 'min_child_samples': 39, 'feature_fraction': 0.9143481373629052, 'bagging_fraction': 0.6210339233068227}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [360]	valid_0's rmse: 4.3492
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:19,070] Trial 30 finished with value: 0.6555175557453298 and parameters: {'learning_rate': 0.05991204553317449, 'num_leaves': 33, 'min_child_samples': 31, 'feature_fraction': 0.7767446427320694, 'bagging_fraction': 0.6831678081621992}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [226]	valid_0's rmse: 4.4868
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:22,537] Trial 31 finished with value: 0.6129689544102005 and parameters: {'learning_rate': 0.02843595881285666, 'num_leaves': 54, 'min_child_samples': 32, 'feature_fraction': 0.9747153186661339, 'bagging_fraction': 0.641242287337939}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [260]	valid_0's rmse: 4.27017
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:25,989] Trial 32 finished with value: 0.612588451985789 and parameters: {'learning_rate': 0.02527291199174889, 'num_leaves': 44, 'min_child_samples': 28, 'feature_fraction': 0.9638802568729784, 'bagging_fraction': 0.6254958103384323}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [325]	valid_0's rmse: 4.26334
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:28,570] Trial 33 finished with value: 0.6436125752204926 and parameters: {'learning_rate': 0.056789971250006524, 'num_leaves': 45, 'min_child_samples': 37, 'feature_fraction': 0.8911628535527536, 'bagging_fraction': 0.7856785647684223}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [207]	valid_0's rmse: 4.41541
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:31,848] Trial 34 finished with value: 0.6128507086079062 and parameters: {'learning_rate': 0.022194066523368472, 'num_leaves': 32, 'min_child_samples': 23, 'feature_fraction': 0.97024807383343, 'bagging_fraction': 0.6819522175367893}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [420]	valid_0's rmse: 4.2652
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:36,034] Trial 35 finished with value: 0.6322757799279588 and parameters: {'learning_rate': 0.02268211469761258, 'num_leaves': 34, 'min_child_samples': 20, 'feature_fraction': 0.9321241472847128, 'bagging_fraction': 0.6862179624546246}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [545]	valid_0's rmse: 4.36609
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:39,655] Trial 36 finished with value: 0.6113933363133544 and parameters: {'learning_rate': 0.021263204430142783, 'num_leaves': 38, 'min_child_samples': 22, 'feature_fraction': 0.9978919517687901, 'bagging_fraction': 0.6021554536931168}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [400]	valid_0's rmse: 4.26255
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:44,520] Trial 37 finished with value: 0.6134772403034957 and parameters: {'learning_rate': 0.014672606056196982, 'num_leaves': 42, 'min_child_samples': 27, 'feature_fraction': 0.9969874998200031, 'bagging_fraction': 0.6189933422207311}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [515]	valid_0's rmse: 4.2631
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:48,279] Trial 38 finished with value: 0.6523468375324865 and parameters: {'learning_rate': 0.037852275391371745, 'num_leaves': 60, 'min_child_samples': 16, 'feature_fraction': 0.8837187515673419, 'bagging_fraction': 0.6290813640389886}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [261]	valid_0's rmse: 4.48252
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:51,121] Trial 39 finished with value: 0.6477207792298353 and parameters: {'learning_rate': 0.04289007631870387, 'num_leaves': 49, 'min_child_samples': 21, 'feature_fraction': 0.9170059660049881, 'bagging_fraction': 0.60304629160538}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [243]	valid_0's rmse: 4.45194
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:54,528] Trial 40 finished with value: 0.6121836839283106 and parameters: {'learning_rate': 0.02350959395191879, 'num_leaves': 39, 'min_child_samples': 28, 'feature_fraction': 0.9842748222102202, 'bagging_fraction': 0.6639538512065735}. Best is trial 1 with value: 0.6112572694107867.
# Early stopping, best iteration is:
# [370]	valid_0's rmse: 4.26792
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:13:58,201] Trial 41 finished with value: 0.6101556770895106 and parameters: {'learning_rate': 0.022215182213414317, 'num_leaves': 38, 'min_child_samples': 29, 'feature_fraction': 0.9798374157484908, 'bagging_fraction': 0.6556572193035426}. Best is trial 41 with value: 0.6101556770895106.
# Early stopping, best iteration is:
# [402]	valid_0's rmse: 4.25916
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:14:01,835] Trial 42 finished with value: 0.6143021948797335 and parameters: {'learning_rate': 0.01844914865142383, 'num_leaves': 37, 'min_child_samples': 34, 'feature_fraction': 0.9795050386401539, 'bagging_fraction': 0.6519687605448732}. Best is trial 41 with value: 0.6101556770895106.
# Early stopping, best iteration is:
# [420]	valid_0's rmse: 4.27142
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:14:07,792] Trial 43 finished with value: 0.6123523118031924 and parameters: {'learning_rate': 0.011431771551132626, 'num_leaves': 28, 'min_child_samples': 29, 'feature_fraction': 0.9887265130936796, 'bagging_fraction': 0.6718516363978484}. Best is trial 41 with value: 0.6101556770895106.
# Early stopping, best iteration is:
# [815]	valid_0's rmse: 4.26203
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:14:12,289] Trial 44 finished with value: 0.6400850698176334 and parameters: {'learning_rate': 0.030499134236519735, 'num_leaves': 39, 'min_child_samples': 22, 'feature_fraction': 0.93505342957292, 'bagging_fraction': 0.6983690580589227}. Best is trial 41 with value: 0.6101556770895106.
# Early stopping, best iteration is:
# [419]	valid_0's rmse: 4.41147
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:14:15,424] Trial 45 finished with value: 0.6133159137286254 and parameters: {'learning_rate': 0.03524028161489455, 'num_leaves': 49, 'min_child_samples': 26, 'feature_fraction': 0.9813477345832053, 'bagging_fraction': 0.730474847385988}. Best is trial 41 with value: 0.6101556770895106.
# Early stopping, best iteration is:
# [248]	valid_0's rmse: 4.27965
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 4.55972
# [I 2026-06-17 11:14:22,947] Trial 46 finished with value: 0.6708800974439693 and parameters: {'learning_rate': 0.0224591497131819, 'num_leaves': 30, 'min_child_samples': 18, 'feature_fraction': 0.7037147562577173, 'bagging_fraction': 0.6352147175506845}. Best is trial 41 with value: 0.6101556770895106.
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:14:24,292] Trial 47 finished with value: 0.6104574635149055 and parameters: {'learning_rate': 0.08940559436189066, 'num_leaves': 38, 'min_child_samples': 31, 'feature_fraction': 0.9968894706384925, 'bagging_fraction': 0.6086418117753093}. Best is trial 41 with value: 0.6101556770895106.
# Early stopping, best iteration is:
# [89]	valid_0's rmse: 4.24427
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:14:26,065] Trial 48 finished with value: 0.6152706137437016 and parameters: {'learning_rate': 0.09072784981235359, 'num_leaves': 60, 'min_child_samples': 35, 'feature_fraction': 0.9965956269326822, 'bagging_fraction': 0.6077334030059818}. Best is trial 41 with value: 0.6101556770895106.
# Early stopping, best iteration is:
# [89]	valid_0's rmse: 4.277
# Training until validation scores don't improve for 50 rounds
# [I 2026-06-17 11:14:28,489] Trial 49 finished with value: 0.6503548671813081 and parameters: {'learning_rate': 0.086321722556624, 'num_leaves': 68, 'min_child_samples': 30, 'feature_fraction': 0.940942519098417, 'bagging_fraction': 0.6038617945539135}. Best is trial 41 with value: 0.6101556770895106.
# Early stopping, best iteration is:
# [112]	valid_0's rmse: 4.47474
# Best params: {'learning_rate': 0.022215182213414317, 'num_leaves': 38, 'min_child_samples': 29, 'feature_fraction': 0.9798374157484908, 'bagging_fraction': 0.6556572193035426}
# Best val MAPE: 0.6101556770895106

# %%
"""
learning_rate': 0.01079893296273494, 'num_leaves': 35, 'min_child_samples': 32, 'feature_fraction': 0.9529657821418857, 'bagging_fraction': 0.7162112140969443
"""
# Out:
# "\nlearning_rate': 0.01079893296273494, 'num_leaves': 35, 'min_child_samples': 32, 'feature_fraction': 0.9529657821418857, 'bagging_fraction': 0.7162112140969443\n"

# %%
# After study.optimize finishes
print('Best params:', study.best_params)
print('Best val MAPE:', study.best_value)

# Retrain with best params on train+val combined, test on 2026
best_params = study.best_params
best_params.update({
    'objective':   'regression',
    'metric':      'rmse',
    'bagging_freq': 5,
    'verbose':     -1
})

# Combine train + val for final model
X_trainval = pd.concat([X_train, X_val])
y_trainval = pd.concat([y_train, y_val])

final_train = lgb.Dataset(X_trainval, label=y_trainval)
final_val   = lgb.Dataset(X_test,     label=y_test)

final_model = lgb.train(
    best_params,
    final_train,
    num_boost_round=study.best_trial.user_attrs.get('best_iteration', 3000),
    valid_sets=[final_val],
    callbacks=[lgb.early_stopping(50), lgb.log_evaluation(100)]
)

# Final evaluation
y_pred = final_model.predict(X_test)
mape   = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
rmse   = np.sqrt(np.mean((y_test - y_pred) ** 2))
mae    = np.mean(np.abs(y_test - y_pred))

print(f'Final Test MAPE: {mape:.2f}%')
print(f'Final Test RMSE: {rmse:.2f} MW')
print(f'Final Test MAE:  {mae:.2f} MW')
# Out:
# Best params: {'learning_rate': 0.022215182213414317, 'num_leaves': 38, 'min_child_samples': 29, 'feature_fraction': 0.9798374157484908, 'bagging_fraction': 0.6556572193035426}
# Best val MAPE: 0.6101556770895106
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 7.83437
# [200]	valid_0's rmse: 4.3248
# [300]	valid_0's rmse: 3.94229
# [400]	valid_0's rmse: 3.86729
# [500]	valid_0's rmse: 3.85022
# [600]	valid_0's rmse: 3.83439
# [700]	valid_0's rmse: 3.82402
# [800]	valid_0's rmse: 3.82029
# Early stopping, best iteration is:
# [760]	valid_0's rmse: 3.81803
# Final Test MAPE: 0.55%
# Final Test RMSE: 3.82 MW
# Final Test MAE:  2.74 MW

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# All error metrics
mae    = np.mean(np.abs(y_test - y_pred))
rmse   = np.sqrt(np.mean((y_test - y_pred) ** 2))
mse    = np.mean((y_test - y_pred) ** 2)
mape   = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
smape  = np.mean(2 * np.abs(y_test - y_pred) / (np.abs(y_test) + np.abs(y_pred))) * 100
r2     = r2_score(y_test, y_pred)
max_err = np.max(np.abs(y_test - y_pred))
median_ae = np.median(np.abs(y_test - y_pred))

print(f'MAE        : {mae:.2f} MW        — average absolute error')
print(f'RMSE       : {rmse:.2f} MW        — penalizes large errors more')
print(f'MSE        : {mse:.2f}            — squared error')
print(f'MAPE       : {mape:.2f}%          — % error relative to actual')
print(f'SMAPE      : {smape:.2f}%         — symmetric MAPE')
print(f'R2 Score   : {r2:.4f}            — 1.0 is perfect')
print(f'Max Error  : {max_err:.2f} MW     — worst single prediction')
print(f'Median AE  : {median_ae:.2f} MW   — error at 50th percentile')
# Out:
# MAE        : 2.74 MW        — average absolute error
# RMSE       : 3.82 MW        — penalizes large errors more
# MSE        : 14.58            — squared error
# MAPE       : 0.55%          — % error relative to actual
# SMAPE      : 0.55%         — symmetric MAPE
# R2 Score   : 0.9957            — 1.0 is perfect
# Max Error  : 30.85 MW     — worst single prediction
# Median AE  : 2.06 MW   — error at 50th percentile

# %%
import lightgbm as lgb
import pandas as pd
import matplotlib.pyplot as plt

lgb.plot_importance(final_model, max_num_features=15, figsize=(10, 6))
plt.tight_layout()
plt.savefig('feature_importance.png')
plt.show()

# %%
results = pd.DataFrame({
    'actual':    y_test.values,
    'predicted': y_pred
}, index=X_test.index)

plt.figure(figsize=(15, 5))
results['actual'].plot(label='Actual', alpha=0.7)
results['predicted'].plot(label='Predicted', alpha=0.7)
plt.title('MP Power Demand — Actual vs Predicted (2026)')
plt.ylabel('MW')
plt.legend()
plt.tight_layout()
plt.savefig('actual_vs_predicted.png')
plt.show()

# %%
final_model.save_model('mp_lgbm_final.txt')

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
import numpy as np

# Train
rf_model = RandomForestRegressor(
    n_estimators=200,
    max_depth=20,
    min_samples_split=10,
    min_samples_leaf=5,
    max_features=0.8,
    n_jobs=-1,
    random_state=42,
    verbose=1
)

rf_model.fit(X_train, y_train)

# Evaluate on val
y_val_pred = rf_model.predict(X_val)
val_mape   = np.mean(np.abs((y_val - y_val_pred) / y_val)) * 100
print(f'Val MAPE: {val_mape:.2f}%')

# Evaluate on test
y_pred_rf = rf_model.predict(X_test)
mae    = np.mean(np.abs(y_test - y_pred_rf))
rmse   = np.sqrt(np.mean((y_test - y_pred_rf) ** 2))
mape   = np.mean(np.abs((y_test - y_pred_rf) / y_test)) * 100
r2     = r2_score(y_test, y_pred_rf)
max_err = np.max(np.abs(y_test - y_pred_rf))

print(f'MAE      : {mae:.2f} MW')
print(f'RMSE     : {rmse:.2f} MW')
print(f'MAPE     : {mape:.2f}%')
print(f'R2       : {r2:.4f}')
print(f'Max Error: {max_err:.2f} MW')
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:    4.8s
# Val MAPE: 0.65%
# MAE      : 3.19 MW
# RMSE     : 4.39 MW
# MAPE     : 0.64%
# R2       : 0.9943
# Max Error: 31.73 MW
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    5.2s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=10)]: Done 200 out of 200 | elapsed:    0.1s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 200 out of 200 | elapsed:    0.0s finished

# %%
import optuna
from sklearn.ensemble import RandomForestRegressor
import numpy as np

def objective(trial):
    params = {
        'n_estimators':     trial.suggest_int('n_estimators', 100, 500),
        'max_depth':        trial.suggest_int('max_depth', 10, 40),
        'min_samples_split':trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features':     trial.suggest_float('max_features', 0.5, 1.0),
        'n_jobs':           -1,
        'random_state':     42
    }

    model = RandomForestRegressor(**params)
    model.fit(X_train, y_train)

    y_val_pred = model.predict(X_val)
    mape = np.mean(np.abs((y_val - y_val_pred) / y_val)) * 100
    return mape

study_rf = optuna.create_study(direction='minimize')
study_rf.optimize(objective, n_trials=30)  # 30 not 50 — RF is slower per trial

print('Best params:', study_rf.best_params)
print('Best val MAPE:', study_rf.best_value)

# Retrain with best params
best_rf = RandomForestRegressor(**study_rf.best_params, n_jobs=-1, random_state=42)
best_rf.fit(X_trainval, y_trainval)  # train on train+val combined

y_pred_rf = best_rf.predict(X_test)
mape  = np.mean(np.abs((y_test - y_pred_rf) / y_test)) * 100
rmse  = np.sqrt(np.mean((y_test - y_pred_rf) ** 2))
mae   = np.mean(np.abs(y_test - y_pred_rf))
r2    = r2_score(y_test, y_pred_rf)

print(f'Final Test MAPE: {mape:.2f}%')
print(f'Final Test RMSE: {rmse:.2f} MW')
print(f'Final Test MAE:  {mae:.2f} MW')
print(f'Final Test R2:   {r2:.4f}')
# Out:
# [I 2026-06-17 11:14:41,746] A new study created in memory with name: no-name-c177b98f-8bf9-45ff-8cd0-fde0fdde4ace
# [I 2026-06-17 11:14:45,780] Trial 0 finished with value: 0.6479205791554008 and parameters: {'n_estimators': 154, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': 0.9145028569894178}. Best is trial 0 with value: 0.6479205791554008.
# [I 2026-06-17 11:14:48,415] Trial 1 finished with value: 0.6532081461998405 and parameters: {'n_estimators': 116, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': 0.8008652777784993}. Best is trial 0 with value: 0.6479205791554008.
# [I 2026-06-17 11:14:58,401] Trial 2 finished with value: 0.6470991567184997 and parameters: {'n_estimators': 422, 'max_depth': 25, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.9616598728553214}. Best is trial 2 with value: 0.6470991567184997.
# [I 2026-06-17 11:15:02,991] Trial 3 finished with value: 0.6656049704995569 and parameters: {'n_estimators': 234, 'max_depth': 19, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 0.7068426704871993}. Best is trial 2 with value: 0.6470991567184997.
# [I 2026-06-17 11:15:12,203] Trial 4 finished with value: 0.6627389670310094 and parameters: {'n_estimators': 448, 'max_depth': 30, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 0.6752402961668078}. Best is trial 2 with value: 0.6470991567184997.
# [I 2026-06-17 11:15:14,151] Trial 5 finished with value: 0.7332524518219435 and parameters: {'n_estimators': 106, 'max_depth': 21, 'min_samples_split': 18, 'min_samples_leaf': 3, 'max_features': 0.5432685821332649}. Best is trial 2 with value: 0.6470991567184997.
# [I 2026-06-17 11:15:22,551] Trial 6 finished with value: 0.6598645516151742 and parameters: {'n_estimators': 397, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.7616927255466397}. Best is trial 2 with value: 0.6470991567184997.
# [I 2026-06-17 11:15:32,293] Trial 7 finished with value: 0.6756571707207166 and parameters: {'n_estimators': 451, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 0.6191986672799354}. Best is trial 2 with value: 0.6470991567184997.
# [I 2026-06-17 11:15:42,113] Trial 8 finished with value: 0.6728414246942096 and parameters: {'n_estimators': 430, 'max_depth': 37, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.6445343354511108}. Best is trial 2 with value: 0.6470991567184997.
# [I 2026-06-17 11:15:53,978] Trial 9 finished with value: 0.6429794238548378 and parameters: {'n_estimators': 331, 'max_depth': 23, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.9164756895327936}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:16:07,571] Trial 10 finished with value: 0.6538027816948716 and parameters: {'n_estimators': 319, 'max_depth': 38, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8724199713344513}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:16:16,928] Trial 11 finished with value: 0.644740723135182 and parameters: {'n_estimators': 314, 'max_depth': 26, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 0.9842512477181277}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:16:23,669] Trial 12 finished with value: 0.686840090448621 and parameters: {'n_estimators': 316, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 0.9599715946890773}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:16:33,109] Trial 13 finished with value: 0.6482000435658061 and parameters: {'n_estimators': 288, 'max_depth': 33, 'min_samples_split': 12, 'min_samples_leaf': 1, 'max_features': 0.9931771305090127}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:16:38,741] Trial 14 finished with value: 0.6501432127594307 and parameters: {'n_estimators': 247, 'max_depth': 26, 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_features': 0.872044099113537}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:16:47,525] Trial 15 finished with value: 0.6482865664673211 and parameters: {'n_estimators': 369, 'max_depth': 24, 'min_samples_split': 20, 'min_samples_leaf': 3, 'max_features': 0.8263653223736327}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:17:00,843] Trial 16 finished with value: 0.6453542113191959 and parameters: {'n_estimators': 494, 'max_depth': 31, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 0.9136022558290342}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:17:11,601] Trial 17 finished with value: 0.6432148133381017 and parameters: {'n_estimators': 344, 'max_depth': 34, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': 0.9954088048316203}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:17:24,519] Trial 18 finished with value: 0.6442923140496124 and parameters: {'n_estimators': 360, 'max_depth': 35, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 0.9062413148366553}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:17:30,911] Trial 19 finished with value: 0.6478271080547926 and parameters: {'n_estimators': 232, 'max_depth': 34, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': 0.8363637988697026}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:17:39,261] Trial 20 finished with value: 0.656899252439173 and parameters: {'n_estimators': 366, 'max_depth': 40, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 0.7637403267112423}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:17:50,303] Trial 21 finished with value: 0.6443091524704092 and parameters: {'n_estimators': 366, 'max_depth': 36, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 0.9262997389395332}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:17:57,136] Trial 22 finished with value: 0.6469169501091303 and parameters: {'n_estimators': 274, 'max_depth': 33, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': 0.8746647198810714}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:18:09,117] Trial 23 finished with value: 0.6453085156072031 and parameters: {'n_estimators': 361, 'max_depth': 40, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 0.9356555539594433}. Best is trial 9 with value: 0.6429794238548378.
# [I 2026-06-17 11:18:15,110] Trial 24 finished with value: 0.642463448453749 and parameters: {'n_estimators': 193, 'max_depth': 30, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 0.9987952473030559}. Best is trial 24 with value: 0.642463448453749.
# [I 2026-06-17 11:18:22,104] Trial 25 finished with value: 0.6428663719991378 and parameters: {'n_estimators': 207, 'max_depth': 30, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_features': 0.9878259141679573}. Best is trial 24 with value: 0.642463448453749.
# [I 2026-06-17 11:18:28,015] Trial 26 finished with value: 0.6422281933190509 and parameters: {'n_estimators': 172, 'max_depth': 29, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 0.9529276997342319}. Best is trial 26 with value: 0.6422281933190509.
# [I 2026-06-17 11:18:34,374] Trial 27 finished with value: 0.644414915179231 and parameters: {'n_estimators': 178, 'max_depth': 29, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 0.9596434735116071}. Best is trial 26 with value: 0.6422281933190509.
# [I 2026-06-17 11:18:41,346] Trial 28 finished with value: 0.6438190103272108 and parameters: {'n_estimators': 196, 'max_depth': 31, 'min_samples_split': 17, 'min_samples_leaf': 4, 'max_features': 0.9989804039197825}. Best is trial 26 with value: 0.6422281933190509.
# [I 2026-06-17 11:18:45,612] Trial 29 finished with value: 0.6437807056102034 and parameters: {'n_estimators': 145, 'max_depth': 28, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': 0.9544177021740483}. Best is trial 26 with value: 0.6422281933190509.
# Best params: {'n_estimators': 172, 'max_depth': 29, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 0.9529276997342319}
# Best val MAPE: 0.6422281933190509
# Final Test MAPE: 0.61%
# Final Test RMSE: 4.21 MW
# Final Test MAE:  3.04 MW
# Final Test R2:   0.9948

# %%
# Simple average ensemble
y_pred_ensemble = (y_pred * 0.5) + (y_pred_rf * 0.5)

mae   = np.mean(np.abs(y_test - y_pred_ensemble))
rmse  = np.sqrt(np.mean((y_test - y_pred_ensemble) ** 2))
mape  = np.mean(np.abs((y_test - y_pred_ensemble) / y_test)) * 100
r2    = r2_score(y_test, y_pred_ensemble)

print(f'Ensemble MAPE: {mape:.3f}%')
print(f'Ensemble RMSE: {rmse:.2f} MW')
print(f'Ensemble MAE:  {mae:.2f} MW')
print(f'Ensemble R2:   {r2:.4f}')
# Out:
# Ensemble MAPE: 0.570%
# Ensemble RMSE: 3.95 MW
# Ensemble MAE:  2.84 MW
# Ensemble R2:   0.9954

# %%
# Try different weights
for lgbm_w in [0.4, 0.5, 0.6, 0.7]:
    rf_w = 1 - lgbm_w
    y_blend = (y_pred * lgbm_w) + (y_pred_rf * rf_w)
    mape = np.mean(np.abs((y_test - y_blend) / y_test)) * 100
    rmse = np.sqrt(np.mean((y_test - y_blend) ** 2))
    print(f'LGBM {lgbm_w:.0%} / RF {rf_w:.0%} → MAPE: {mape:.3f}%, RMSE: {rmse:.2f}')
# Out:
# LGBM 40% / RF 60% → MAPE: 0.576%, RMSE: 3.99
# LGBM 50% / RF 50% → MAPE: 0.570%, RMSE: 3.95
# LGBM 60% / RF 40% → MAPE: 0.564%, RMSE: 3.91
# LGBM 70% / RF 30% → MAPE: 0.560%, RMSE: 3.88

# %%
y_pred_final = (y_pred * 0.6) + (y_pred_rf * 0.4)

mae   = np.mean(np.abs(y_test - y_pred_final))
rmse  = np.sqrt(np.mean((y_test - y_pred_final) ** 2))
mape  = np.mean(np.abs((y_test - y_pred_final) / y_test)) * 100
r2    = r2_score(y_test, y_pred_final)
max_err = np.max(np.abs(y_test - y_pred_final))
median_ae = np.median(np.abs(y_test - y_pred_final))

print(f'Final Ensemble MAPE     : {mape:.3f}%')
print(f'Final Ensemble RMSE     : {rmse:.2f} MW')
print(f'Final Ensemble MAE      : {mae:.2f} MW')
print(f'Final Ensemble R2       : {r2:.4f}')
print(f'Final Ensemble Max Error: {max_err:.2f} MW')
print(f'Final Ensemble Median AE: {median_ae:.2f} MW')
# Out:
# Final Ensemble MAPE     : 0.564%
# Final Ensemble RMSE     : 3.91 MW
# Final Ensemble MAE      : 2.81 MW
# Final Ensemble R2       : 0.9955
# Final Ensemble Max Error: 31.01 MW
# Final Ensemble Median AE: 2.12 MW

# %%
"""
Best params: {'n_estimators': 258, 'max_depth': 38, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.9294392572105932}
Best val MAPE: 0.7089540681136403
Final Test MAPE: 0.95%
Final Test RMSE: 181.35 MW
Final Test MAE:  130.00 MW
Final Test R2:   0.9962



FOR RF
"""
# Out:
# "\nBest params: {'n_estimators': 258, 'max_depth': 38, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.9294392572105932}\nBest val MAPE: 0.7089540681136403\nFinal Test MAPE: 0.95%\nFinal Test RMSE: 181.35 MW\nFinal Test MAE:  130.00 MW\nFinal Test R2:   0.9962\n\n\n\nFOR RF\n"

# %%
"""
Best params: {'learning_rate': 0.01079893296273494, 'num_leaves': 35, 'min_child_samples': 32, 'feature_fraction': 0.9529657821418857, 'bagging_fraction': 0.7162112140969443}
MAE        : 128.21 MW        — average absolute error
RMSE       : 184.27 MW        — penalizes large errors more
MSE        : 33957.11            — squared error
MAPE       : 0.91%          — % error relative to actual
SMAPE      : 0.91%         — symmetric MAPE
R2 Score   : 0.9960            — 1.0 is perfect
Max Error  : 1475.80 MW     — worst single prediction
Median AE  : 92.82 MW   — error at 50th percentile


lightgbm
"""
#better
# Out:
# "\nBest params: {'learning_rate': 0.01079893296273494, 'num_leaves': 35, 'min_child_samples': 32, 'feature_fraction': 0.9529657821418857, 'bagging_fraction': 0.7162112140969443}\nMAE        : 128.21 MW        — average absolute error\nRMSE       : 184.27 MW        — penalizes large errors more\nMSE        : 33957.11            — squared error\nMAPE       : 0.91%          — % error relative to actual\nSMAPE      : 0.91%         — symmetric MAPE\nR2 Score   : 0.9960            — 1.0 is perfect\nMax Error  : 1475.80 MW     — worst single prediction\nMedian AE  : 92.82 MW   — error at 50th percentile\n\n\nlightgbm\n"

# %%
# best param 
# LGBM 60% / RF 40% → MAPE: 0.890%, RMSE: 172.23

# %%
import shap

explainer = shap.TreeExplainer(final_model)
shap_values = explainer.shap_values(X_test)

# Summary plot — feature importance by impact
shap.summary_plot(shap_values, X_test)

# Single prediction explanation
shap.waterfall_plot(explainer(X_test.iloc[0]))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/lightgbm/basic.py:1238: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning("Converting data to scipy sparse matrix.")
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 10
#       7 shap.summary_plot(shap_values, X_test)
#       9 # Single prediction explanation
# ---> 10 shap.waterfall_plot(explainer(X_test.iloc[0]))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/shap/explainers/_tree.py:391, in TreeExplainer.__call__(self, X, y, interactions, check_additivity, approximate)
#     388     feature_names = getattr(self, "data_feature_names", None)
#     390 if not interactions:
# --> 391     v = self.shap_values(X, y=y, from_call=True, check_additivity=check_additivity, approximate=approximate)
#     392     if isinstance(v, list):
#     393         v = np.stack(v, axis=-1)  # put outputs at the end
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/shap/explainers/_tree.py:635, in TreeExplainer.shap_values(self, X, y, tree_limit, approximate, check_additivity, from_call)
#     631     if not from_call:
#     632         warnings.warn(
#     633             "LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray"
#     634         )
# --> 635 if phi.shape[1] != X.shape[1] + 1:
#     636     try:
#     637         phi = phi.reshape(X.shape[0], phi.shape[1] // (X.shape[1] + 1), X.shape[1] + 1)
#
# IndexError: tuple index out of range

# %%
final_model.save_model('Goa_lgbm_final.txt')

# %%
import pickle

# Assume model is already trained
with open("model.pkl", "wb") as file:
    pickle.dump(model, file)
